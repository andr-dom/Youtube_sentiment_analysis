# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import  warnings
warnings.filterwarnings("ignore")

# %%
#librerias para analisis de texto
import nltk

# %%
from ntlk.sentiment.vader import Sentimen
